# %%
from dotenv import load_dotenv, find_dotenv; load_dotenv(find_dotenv())
import os, notion_client

notion = notion_client.Client(auth=os.environ['NOTION_TOKEN'])
CLIP = os.environ['CLIP_DATABSE_ID']
INPUT = os.environ['INPUT_DATABSE_ID']

# %%
def remove_keys(d):
    keys_to_remove = ['id', 'color', 'description']
    for k in keys_to_remove:
        d.pop(k, None)
    for k, v in d.items():
        if isinstance(v, dict):
            remove_keys(v)
        elif isinstance(v, list):
            for v_ in v:
                if isinstance(v_, dict):
                    remove_keys(v_)

# %%
database = notion.databases.retrieve(database_id=INPUT)
remove_keys(database)
# display(database)
database['properties']
# Out:
# {'URL': {'name': 'URL', 'type': 'url', 'url': {}},
#  'Year': {'name': 'Year',
#   'type': 'multi_select',
#   'multi_select': {'options': [{'name': '2024'},
#     {'name': '2024.05'},
#     {'name': '2024.04'},
#     {'name': '2024.03'},
#     {'name': '2024.02'},
#     {'name': '2024.01'},
#     {'name': '2023'},
#     {'name': '2023.12'},
#     {'name': '2023.11'},
#     {'name': '2023.10'},
#     {'name': '2023.09'},
#     {'name': '2023.08'},
#     {'name': '2023.07'},
#     {'name': '2023.06'},
#     {'name': '2023.05'},
#     {'name': '2023.03'},
#     {'name': '2023.01'},
#     {'name': '2022'},
#     {'name': '2021'},
#     {'name': '2020'},
#     {'name': '2019'},
#     {'name': '2016'},
#     {'name': '2015'},
#     {'name': '2013'}]}},
#  'Priority': {'name': 'Priority',
#   'type': 'select',
#   'select': {'options': [{'name': 'SuperHigh'},
#     {'name': 'High'},
#     {'name': 'Medium'},
#     {'name': 'Low'},
#     {'name': 'Waiting'}]}},
#  'Type': {'name': 'Type',
#   'type': 'multi_select',
#   'multi_select': {'options': [{'name': 'Tweet'},
#     {'name': 'Announce'},
#     {'name': 'Slides'},
#     {'name': 'Medium'},
#     {'name': 'Web'},
#     {'name': 'Qiita'},
#     {'name': 'Zenn'},
#     {'name': 'Notion'},
#     {'name': 'note'},
#     {'name': 'Book'},
#     {'name': 'Paper'},
#     {'name': 'GitHub'},
#     {'name': 'HuggingFace'},
#     {'name': 'Demo'},
#     {'name': 'KAKEN'},
#     {'name': 'Course'},
#     {'name': 'Tutorial'},
#     {'name': 'Resources'},
#     {'name': 'GPTs'},
#     {'name': 'Thought'},
#     {'name': 'Youtube'},
#     {'name': 'Webinar'},
#     {'name': 'Kaggle'},
#     {'name': 'Service'},
#     {'name': 'MemberOnly'}]}},
#  'Tags': {'name': 'Tags',
#   'type': 'multi_select',
#   'multi_select': {'options': [{'name': 'LLM'},
#     {'name': 'LLMEval'},
#     {'name': 'LLMOps'},
#     {'name': 'Agent'},
#     {'name': 'ChatGPT'},
#     {'name': 'OpenAI'},
#     {'name': 'VoiceInteraction'},
#     {'name': 'Prompt'},
#     {'name': 'GA'},
#     {'name': 'Guardrails'},
#     {'name': 'LangChain'},
#     {'name': 'SoftDev'},
#     {'name': 'OpenLLM'},
#     {'name': 'AWS'},
#     {'name': 'Life'},
#     {'name': 'CustomInstructions'},
#     {'name': 'Survey'},
#     {'name': 'Azure'},
#     {'name': 'Embedding'},
#     {'name': 'Visualization'},
#     {'name': 'Conversation'},
#     {'name': 'Robotics'},
#     {'name': 'Container'},
#     {'name': 'FastAPI'},
#     {'name': 'Reseach'},
#     {'name': 'Python'},
#     {'name': 'Database'},
#     {'name': 'RAG'},
#     {'name': 'OpenSearch'},
#     {'name': 'SQL'},
#     {'name': 'GPT4V'},
#     {'name': 'StableDiffusion'},
#     {'name': 'Logging'},
#     {'name': 'DX'},
#     {'name': 'ECS'},
#     {'name': 'Geo'},
#     {'name': 'Infrastructure'},
#     {'name': 'Kaggle'},
#     {'name': 'LangSmith'},
#     {'name': 'PromptHub'},
#     {'name': 'PromptRefine'},
#     {'name': 'Notion'},
#     {'name': 'LLMTuning'},
#     {'name': 'Rec'},
#     {'name': 'PrivateDev'},
#     {'name': 'English'},
#     {'name': 'SelfManagement'},
#     {'name': 'Chat'},
#     {'name': 'KnowledgeGraph'},
#     {'name': 'IaC'},
#     {'name': 'UIdev'},
#     {'name': 'AssistantsAPI'},
#     {'name': 'ML'},
#     {'name': 'HitL'},
#     {'name': 'QueryTrans'},
#     {'name': 'Decision'},
#     {'name': 'GPTs'},
#     {'name': 'Experiments'},
#     {'name': 'JsonMode'},
#     {'name': 'OpenInterpreter'},
#     {'name': 'Flutter'},
#     {'name': 'Service'},
#     {'name': 'MySQL'},
#     {'name': 'ChatInteraction'},
#     {'name': 'Copilot'},
#     {'name': 'Cursor'},
#     {'name': 'Docker'},
#     {'name': 'MultiModal'},
#     {'name': 'MongoDB'},
#     {'name': 'ROS'},
#     {'name': 'Wearable'},
#     {'name': 'DataAnalysis'},
#     {'name': 'Google'},
#     {'name': 'Vision'},
#     {'name': 'Gemini'},
#     {'name': 'HCI'},
#     {'name': 'MQ3'},
#     {'name': 'XR'},
#     {'name': 'Unity'},
#     {'name': 'guidance'},
#     {'name': 'NLP'},
#     {'name': 'Philosophy'},
#     {'name': 'Work'},
#     {'name': 'DDD'},
#     {'name': 'Drawing'},
#     {'name': 'JavaScript'},
#     {'name': 'MoE'},
#     {'name': 'Career'},
#     {'name': 'LlamaIndex'},
#     {'name': 'GenerativeAI'},
#     {'name': 'Manifold'},
#     {'name': 'OCR'},
#     {'name': 'Bandit'},
#     {'name': 'CausalInference'},
#     {'name': 'PromptInjection'},
#     {'name': 'CodeInterpreter'},
#     {'name': 'Food'},
#     {'name': 'Whisper'},
#     {'name': 'Sports'},
#     {'name': 'Claude'},
#     {'name': 'CodeLLM'},
#     {'name': 'Bedrock'},
#     {'name': 'Search'},
#     {'name': 'LLMSecurity'},
#     {'name': 'ReactNative'},
#     {'name': 'UX'},
#     {'name': 'Dataset'},
#     {'name': 'Translate'},
#     {'name': 'WebSearch'},
#     {'name': 'GNN'}]}},
#  'Created': {'name': 'Created', 'type': 'created_time', 'created_time': {}},
#  'PDF': {'name': 'PDF', 'type': 'files', 'files': {}},
#  'Action': {'name': 'Action', 'type': 'rich_text', 'rich_text': {}},
#  'Abstract': {'name': 'Abstract', 'type': 'rich_text', 'rich_text': {}},
#  'Last edited': {'name': 'Last edited',
#   'type': 'last_edited_time',
#   'last_edited_time': {}},
#  'Title': {'name': 'Title', 'type': 'rich_text', 'rich_text': {}},
#  'DOI': {'name': 'DOI', 'type': 'rich_text', 'rich_text': {}},
#  'Code': {'name': 'Code', 'type': 'url', 'url': {}},
#  'Relation': {'name': 'Relation',
#   'type': 'relation',
#   'relation': {'database_id': 'b97a725c-57d7-4939-b9b4-14aeb57979a7',
#    'type': 'single_property',
#    'single_property': {}}},
#  'Check': {'name': 'Check', 'type': 'checkbox', 'checkbox': {}},
#  'Status': {'name': 'Status',
#   'type': 'status',
#   'status': {'options': [{'name': 'Imported'},
#     {'name': 'Pending'},
#     {'name': 'Not started'},
#     {'name': 'In progress'},
#     {'name': 'Done'}],
#    'groups': [{'name': 'To-do',
#      'option_ids': ['XTXj', ':;jE', '83ce31fd-9d97-4795-845f-465b31793412']},
#     {'name': 'In progress',
#      'option_ids': ['54b2af0f-1eec-4a7d-bf9e-ca8e8c34c959']},
#     {'name': 'Complete',
#      'option_ids': ['8233b0ad-d969-4135-87ab-74dfec3928d0']}]}},
#  'Issue': {'name': 'Issue', 'type': 'title', 'title': {}}}

# %%
tags = [o['name'] for o in database['properties']['Tags']['multi_select']['options']]
types = [o['name'] for o in database['properties']['Type']['multi_select']['options']]

# %%
import requests, datetime
from bs4 import BeautifulSoup
from typing import Optional
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_community.document_loaders.html import UnstructuredHTMLLoader
from langchain_core.messages import SystemMessage
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI
from langchain.output_parsers.openai_functions import JsonOutputFunctionsParser
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_core.utils.function_calling import convert_to_openai_function, convert_to_openai_tool

# %%
class PageProperties(BaseModel):
    """Extract web page data"""
    title: str = Field(..., description='page title')
    short_title: str = Field(..., description='page title (short ver.)')
    year: Optional[int] = Field(description='Posted year of the page')
    month: Optional[int] = Field(description='Posted month of the page')
    # date: Optional[datetime.date] = Field(description='Posted date of the page in format "%Y/%m/%d"')
    types: list[str] = Field(..., description='page types in list. You can create new.', enum=types)
    tags: list[str] = Field(..., description='tags in list. You can create new in Camel case.', enum=tags)
    summary: str = Field(..., description='page content in Japanese.')
    # code: Optional[str] = Field(description='link url to the Code. (Github, GitLab, ...)')
    # pdf: Optional[str] = Field(description='link url to the PDF.')

extract_func = convert_to_openai_function(PageProperties)
extract_func
# Out:
# {'name': 'PageProperties',
#  'description': 'Extract web page data',
#  'parameters': {'type': 'object',
#   'properties': {'title': {'description': 'page title', 'type': 'string'},
#    'short_title': {'description': 'page title (short ver.)', 'type': 'string'},
#    'year': {'description': 'Posted year of the page', 'type': 'integer'},
#    'month': {'description': 'Posted month of the page', 'type': 'integer'},
#    'types': {'description': 'page types in list. You can create new.',
#     'enum': ['Tweet',
#      'Announce',
#      'Slides',
#      'Medium',
#      'Web',
#      'Qiita',
#      'Zenn',
#      'Notion',
#      'note',
#      'Book',
#      'Paper',
#      'GitHub',
#      'HuggingFace',
#      'Demo',
#      'KAKEN',
#      'Course',
#      'Tutorial',
#      'Resources',
#      'GPTs',
#      'Thought',
#      'Youtube',
#      'Webinar',
#      'Kaggle',
#      'Service',
#      'MemberOnly'],
#     'type': 'array',
#     'items': {'type': 'string'}},
#    'tags': {'description': 'tags in list. You can create new in Camel case.',
#     'enum': ['LLM',
#      'LLMEval',
#      'LLMOps',
#      'Agent',
#      'ChatGPT',
#      'OpenAI',
#      'VoiceInteraction',
#      'Prompt',
#      'GA',
#      'Guardrails',
#      'LangChain',
#      'SoftDev',
#      'OpenLLM',
#      'AWS',
#      'Life',
#      'CustomInstructions',
#      'Survey',
#      'Azure',
#      'Embedding',
#      'Visualization',
#      'Conversation',
#      'Robotics',
#      'Container',
#      'FastAPI',
#      'Reseach',
#      'Python',
#      'Database',
#      'RAG',
#      'OpenSearch',
#      'SQL',
#      'GPT4V',
#      'StableDiffusion',
#      'Logging',
#      'DX',
#      'ECS',
#      'Geo',
#      'Infrastructure',
#      'Kaggle',
#      'LangSmith',
#      'PromptHub',
#      'PromptRefine',
#      'Notion',
#      'LLMTuning',
#      'Rec',
#      'PrivateDev',
#      'English',
#      'SelfManagement',
#      'Chat',
#      'KnowledgeGraph',
#      'IaC',
#      'UIdev',
#      'AssistantsAPI',
#      'ML',
#      'HitL',
#      'QueryTrans',
#      'Decision',
#      'GPTs',
#      'Experiments',
#      'JsonMode',
#      'OpenInterpreter',
#      'Flutter',
#      'Service',
#      'MySQL',
#      'ChatInteraction',
#      'Copilot',
#      'Cursor',
#      'Docker',
#      'MultiModal',
#      'MongoDB',
#      'ROS',
#      'Wearable',
#      'DataAnalysis',
#      'Google',
#      'Vision',
#      'Gemini',
#      'HCI',
#      'MQ3',
#      'XR',
#      'Unity',
#      'guidance',
#      'NLP',
#      'Philosophy',
#      'Work',
#      'DDD',
#      'Drawing',
#      'JavaScript',
#      'MoE',
#      'Career',
#      'LlamaIndex',
#      'GenerativeAI',
#      'Manifold',
#      'OCR',
#      'Bandit',
#      'CausalInference',
#      'PromptInjection',
#      'CodeInterpreter',
#      'Food',
#      'Whisper',
#      'Sports',
#      'Claude',
#      'CodeLLM',
#      'Bedrock',
#      'Search',
#      'LLMSecurity',
#      'ReactNative',
#      'UX',
#      'Dataset',
#      'Translate',
#      'WebSearch',
#      'GNN'],
#     'type': 'array',
#     'items': {'type': 'string'}},
#    'summary': {'description': 'page content in Japanese.', 'type': 'string'}},
#   'required': ['title', 'short_title', 'types', 'tags', 'summary']}}

# %%
def load_doc(url):
    response = requests.get(url)
    with open('temp.html','w') as f:
        f.write(response.text)
    loader = UnstructuredHTMLLoader("temp.html")
    docs = loader.load()
    content = docs[0].page_content.replace('\n\n', '\n')
    return content

def extract_urls(url):
    headers = {
        'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }
    response = requests.request("GET", url, headers=headers)
    data = BeautifulSoup(response.text, 'html.parser')
    urls = data.find_all('a', href=True)
    return urls

# %%
model = ChatOpenAI(model='gpt-3.5-turbo')
model_with_func = model.bind_functions([extract_func])

# %%
system_images_extract = '''\
You are a data extractor from a web page.
'''

template = '''\
## SourceURL
{source_url}

## WebText
{web_text}
'''

# ## URLsInPage
# {urls}

chat_template = ChatPromptTemplate.from_messages([
    SystemMessage(content=system_images_extract),
    HumanMessagePromptTemplate.from_template(template),
])

# %%
def create_page(x):
    page = {
        "parent": { "database_id": INPUT},
        "properties": {
            'Status': {'status': {'name': 'Imported'}},
            'Issue': {'title': [{'text': {'content': x['short_title']}}]},
            'Type': {"multi_select": [
                {'name': typ}
                for typ in x['types']
            ]},
            'Tags': {"multi_select": [
                {'name': tag}
                for tag in x['tags']
            ]},
            'Abstract': {'rich_text': [{'text': {'content': x['summary']}}]},
            'Title': {'rich_text': [{'text': {'content': x['title']}}]},
        }
    }
    if 'year' in x:
        year = []
        if x['year'] >= 2023:
            if 'month' in x:
                year.append({'name': f"{str(x['year']).zfill(4)}.{str(x['month']).zfill(2)}"}),
                year.append({'name': str(x['year'])})
        else:
            year.append({'name': str(x['year'])})
        if year:
            page['properties']['Year'] = {"multi_select": year}
    return page

# %%
chain = {
    'source_url': RunnablePassthrough(),
    'web_text': RunnablePassthrough() | RunnableLambda(load_doc),
    'urls': RunnablePassthrough() | RunnableLambda(extract_urls),
} | RunnablePassthrough() \
| chat_template | model_with_func | JsonOutputFunctionsParser() \
| RunnableLambda(create_page)

# %%
# url = 'https://zenn.dev/ysksatoo/articles/66fd26893a6cdd'
url = 'https://juu7g.hatenablog.com/entry/Python/blog/notion-api#%E3%83%87%E3%83%BC%E3%82%BF%E3%83%99%E3%83%BC%E3%82%B9%E3%81%AE%E3%83%97%E3%83%AD%E3%83%91%E3%83%86%E3%82%A3%E3%81%AB%E5%90%88%E3%81%A3%E3%81%9F%E3%83%97%E3%83%AD%E3%83%91%E3%83%86%E3%82%A3%E5%80%A4%E3%81%AE%E4%BD%9C%E3%82%8A%E6%96%B9'
res = chain.invoke(url)

# %%
res
# Out:
# {'parent': {'database_id': 'b97a725c57d74939b9b414aeb57979a7'},
#  'properties': {'Status': {'status': {'name': 'Imported'}},
#   'Issue': {'title': [{'text': {'content': 'PythonでのNotion API'}}]},
#   'Type': {'multi_select': [{'name': 'Web'}]},
#   'Tags': {'multi_select': [{'name': 'Python'},
#     {'name': 'Notion'},
#     {'name': 'API'}]},
#   'Abstract': {'rich_text': [{'text': {'content': 'PythonでNotion APIを操作する方法について紹介しています。記事ではnotion-clientパッケージを使用して、Notionデータベースにデータを追加、更新、削除する方法やデータベースのプロパティ値の作り方などについて解説しています。また、Notion APIの各種設定値や環境変数の設定方法、実際のプログラムの実践例も紹介しています。'}}]},
#   'Title': {'rich_text': [{'text': {'content': 'PythonでのNotion APIの使い方'}}]},
#   'Year': {'multi_select': [{'name': '2022'}]}}}

# %%
notion.pages.create(**res)
# Out:
# {'object': 'page',
#  'id': '56121ddc-ce3d-46dd-aa8a-7384db57cee2',
#  'created_time': '2024-05-20T23:37:00.000Z',
#  'last_edited_time': '2024-05-20T23:37:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '79657b4f-a71f-4ee8-8fc7-b5b4d6e6f385'},
#  'last_edited_by': {'object': 'user',
#   'id': '79657b4f-a71f-4ee8-8fc7-b5b4d6e6f385'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'b97a725c-57d7-4939-b9b4-14aeb57979a7'},
#  'archived': False,
#  'in_trash': False,
#  'properties': {'URL': {'id': 'CcZw', 'type': 'url', 'url': None},
#   'Year': {'id': 'ECqv',
#    'type': 'multi_select',
#    'multi_select': [{'id': 'e542b25a-23ba-4a6f-bae2-f4746380969f',
#      'name': '2022',
#      'color': 'red'}]},
#   'Priority': {'id': 'G%60Y%7B', 'type': 'select', 'select': None},
#   'Type': {'id': 'UZhN',
#    'type': 'multi_select',
#    'multi_select': [{'id': 'badbe344-c582-4ad1-882d-a6e78c96530a',
#      'name': 'Web',
#      'color': 'brown'}]},
#   'Reports': {'id': '%5CxHy',
#    'type': 'relation',
#    'relation': [],
#    'has_more': False},
#   'Tags': {'id': '_%5Chb',
#    'type': 'multi_select',
#    'multi_select': [{'id': '314af069-129d-4f5e-ab80-c6e851f37d06',
#      'name': 'Python',
#      'color': 'yellow'},
#     {'id': 'b2d59d5b-02d5-45e8-982a-9d51989ea674',
#      'name': 'Notion',
#      'color': 'default'},
#     {'id': 'ae42f1cf-e0f6-4f80-af45-0dde23e20d2d',
#      'name': 'API',
#      'color': 'orange'}]},
#   'Created': {'id': 'dUrz',
#    'type': 'created_time',
#    'created_time': '2024-05-20T23:37:00.000Z'},
#   'PDF': {'id': 'eHSC', 'type': 'files', 'files': []},
#   'Action': {'id': 'eic%5C', 'type': 'rich_text', 'rich_text': []},
#   'Abstract': {'id': 'fNJj',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': 'PythonでNotion APIを操作する方法について紹介しています。記事ではnotion-clientパッケージを使用して、Notionデータベースにデータを追加、更新、削除する方法やデータベースのプロパティ値の作り方などについて解説しています。また、Notion APIの各種設定値や環境変数の設定方法、実際のプログラムの実践例も紹介しています。',
#       'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'PythonでNotion APIを操作する方法について紹介しています。記事ではnotion-clientパッケージを使用して、Notionデータベースにデータを追加、更新、削除する方法やデータベースのプロパティ値の作り方などについて解説しています。また、Notion APIの各種設定値や環境変数の設定方法、実際のプログラムの実践例も紹介しています。',
#      'href': None}]},
#   'Last edited': {'id': 'lw~r',
#    'type': 'last_edited_time',
#    'last_edited_time': '2024-05-20T23:37:00.000Z'},
#   'Title': {'id': 'r%7CRk',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': 'PythonでのNotion APIの使い方', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'PythonでのNotion APIの使い方',
#      'href': None}]},
#   'DOI': {'id': 'tZ%5Bw', 'type': 'rich_text', 'rich_text': []},
#   'Code': {'id': 'vgLc', 'type': 'url', 'url': None},
#   'Relation': {'id': 'xpv%3A',
#    'type': 'relation',
#    'relation': [],
#    'has_more': False},
#   'Check': {'id': '%7BlE%3E', 'type': 'checkbox', 'checkbox': False},
#   'Status': {'id': '~%5BsX',
#    'type': 'status',
#    'status': {'id': 'XTXj', 'name': 'Imported', 'color': 'gray'}},
#   'Issue': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': 'PythonでのNotion API', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': 'PythonでのNotion API',
#      'href': None}]}},
#  'url': 'https://www.notion.so/Python-Notion-API-56121ddcce3d46ddaa8a7384db57cee2',
#  'public_url': None,
#  'request_id': '41df82bf-c0f9-450e-8339-7d290ed0d37e'}
